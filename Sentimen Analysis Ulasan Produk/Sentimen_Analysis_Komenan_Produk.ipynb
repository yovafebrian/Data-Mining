# %%
import pandas as pd
import matplotlib.pyplot as plt
import Sastrawi
from wordcloud import WordCloud
import numpy as np

# %%
df = pd.read_csv('data_real.csv')

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0          59
# 1                1          70
# 2                2          95
# 3                3         117
# 4                4         153
# ...            ...         ...
# 1920           995        1017
# 1921           996        1018
# 1922           997        1019
# 1923           998        1020
# 1924           999        1021
#
#                                                  Ulasan  Rating     Kategori  \
# 0                     Pesanan gx sesuai dgn yg d gambar       2  pertukangan
# 1     Pengiriman dan respon super cepat. Tpi barang ...       2  pertukangan
# 2                barang yg dikirim tidak sesuai pesanan       1  pertukangan
# 3     Php, bilang isi ada diseskripsi pas dipesen be...       1  pertukangan
# 4       barang jelek copot&#34; terus tmpat taro isinya       2  pertukangan
# ...                                                 ...     ...          ...
# 1920           Bagus dan memuaskan. Packing bagus cepat       4  pertukangan
# 1921              Mantap pengiriman ok cepat recomended       5  pertukangan
# 1922                          Pengiriman cepat. Lumayan       4  pertukangan
# 1923                  belom dicoba semoga oke barangnya       4  pertukangan
# 1924  Barang cukup bagus, Respon bagus. Tapi gak ada...       3  pertukangan
#
#                                             Nama Produk  Id Produk Terjual  \
# 0                    Isi Staples Tembak 8 mm best guard  133507638     545
# 1                    Isi Staples Tembak 8 mm best guard  133507638     545
# 2                    Isi Staples Tembak 8 mm best guard  133507638     545
# 3     steples tembak / staples tembak kenmaster PROM...   88842566      45
# 4     Staple Gun / Staples Tembak / Staples Jok / He...  209226141     171
# ...                                                 ...        ...     ...
# 1920  Staples Gun Tacker Mollar 3 in 1 / Staple Jok ...  221298191     408
# 1921  Staples Gun Tacker Mollar 3 in 1 / Staple Jok ...  221298191     408
# 1922  Staples Gun Tacker Mollar 3 in 1 / Staple Jok ...  221298191     408
# 1923  Staples Gun Tacker Mollar 3 in 1 / Staple Jok ...  221298191     408
# 1924  Staples Gun Tacker Mollar 3 in 1 / Staple Jok ...  221298191     408
#
#       Id_Toko                                                Url  label
# 0     1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 1     1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 2     1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 3     1102298  https://www.tokopedia.com/cahayabelawa/steples...      0
# 4      580197  https://www.tokopedia.com/hmhhardware/staple-g...      0
# ...       ...                                                ...    ...
# 1920  1114588  https://www.tokopedia.com/indahjayatools/stapl...      1
# 1921  1114588  https://www.tokopedia.com/indahjayatools/stapl...      1
# 1922  1114588  https://www.tokopedia.com/indahjayatools/stapl...      1
# 1923  1114588  https://www.tokopedia.com/indahjayatools/stapl...      1
# 1924  1114588  https://www.tokopedia.com/indahjayatools/stapl...      1
#
# [1925 rows x 11 columns]

# %%
df = pd.read_csv('data_real.csv', index_col=0)
df.head()
# Out:
#    Unnamed: 0                                             Ulasan  Rating  \
# 0          59                  Pesanan gx sesuai dgn yg d gambar       2
# 1          70  Pengiriman dan respon super cepat. Tpi barang ...       2
# 2          95             barang yg dikirim tidak sesuai pesanan       1
# 3         117  Php, bilang isi ada diseskripsi pas dipesen be...       1
# 4         153    barang jelek copot&#34; terus tmpat taro isinya       2
#
#       Kategori                                        Nama Produk  Id Produk  \
# 0  pertukangan                 Isi Staples Tembak 8 mm best guard  133507638
# 1  pertukangan                 Isi Staples Tembak 8 mm best guard  133507638
# 2  pertukangan                 Isi Staples Tembak 8 mm best guard  133507638
# 3  pertukangan  steples tembak / staples tembak kenmaster PROM...   88842566
# 4  pertukangan  Staple Gun / Staples Tembak / Staples Jok / He...  209226141
#
#   Terjual  Id_Toko                                                Url  label
# 0     545  1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 1     545  1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 2     545  1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 3      45  1102298  https://www.tokopedia.com/cahayabelawa/steples...      0
# 4     171   580197  https://www.tokopedia.com/hmhhardware/staple-g...      0

# %%
df_copy = df.copy()

# %% [markdown]
# ###**LABELING**

# %%
label = []
for index, row in df_copy.iterrows():
  if row["Rating"] == 1 or row["Rating"] == 2:
    label.append(0)
  else :
    label.append(1)

df_copy["label"] = label

# %%
df_copy.head()
# Out:
#    Unnamed: 0                                             Ulasan  Rating  \
# 0          59                  Pesanan gx sesuai dgn yg d gambar       2
# 1          70  Pengiriman dan respon super cepat. Tpi barang ...       2
# 2          95             barang yg dikirim tidak sesuai pesanan       1
# 3         117  Php, bilang isi ada diseskripsi pas dipesen be...       1
# 4         153    barang jelek copot&#34; terus tmpat taro isinya       2
#
#       Kategori                                        Nama Produk  Id Produk  \
# 0  pertukangan                 Isi Staples Tembak 8 mm best guard  133507638
# 1  pertukangan                 Isi Staples Tembak 8 mm best guard  133507638
# 2  pertukangan                 Isi Staples Tembak 8 mm best guard  133507638
# 3  pertukangan  steples tembak / staples tembak kenmaster PROM...   88842566
# 4  pertukangan  Staple Gun / Staples Tembak / Staples Jok / He...  209226141
#
#   Terjual  Id_Toko                                                Url  label
# 0     545  1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 1     545  1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 2     545  1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 3      45  1102298  https://www.tokopedia.com/cahayabelawa/steples...      0
# 4     171   580197  https://www.tokopedia.com/hmhhardware/staple-g...      0

# %% [markdown]
# # C. Preprocessing Teks

# %%
# ngubah text menjadi lower
df_copy['Ulasan'] = df_copy['Ulasan'].str.lower()

# %% [markdown]
# ## C1.Normalisasi

# %%
norm = {" dgn " : " dengan ", " gue ": " saya ", " dgn ":" dengan ", "bgmn ":" bagaimana ", ' tdk':' tidak ', ' blum ':' belum ', 'mantaaaaaaaappp':' bagus ', ' josss ':' bagus ', ' thanks ': ' terima kasih ', 'fast':' cepat ', ' dg ':' dengan ', 'trims':' terima kasih ', 'brg':' barang ', 'gx':' tidak ', ' dgn ':' dengan ', ' recommended':' rekomen ', 'recomend':' rekomen ', 'good':' bagus '}

def normalisasi(str_text):
  for i in norm:
    str_text = str_text.replace(i, norm[i])
  return str_text

df_copy['Ulasan'] = df_copy['Ulasan'].apply(lambda x: normalisasi(x))

# %%
df_copy.head()
# Out:
#    Unnamed: 0                                             Ulasan  Rating  \
# 0          59          pesanan  tidak  sesuai dengan yg d gambar       2
# 1          70  pengiriman dan respon super cepat. tpi barang ...       2
# 2          95             barang yg dikirim tidak sesuai pesanan       1
# 3         117  php, bilang isi ada diseskripsi pas dipesen be...       1
# 4         153    barang jelek copot&#34; terus tmpat taro isinya       2
#
#       Kategori                                        Nama Produk  Id Produk  \
# 0  pertukangan                 Isi Staples Tembak 8 mm best guard  133507638
# 1  pertukangan                 Isi Staples Tembak 8 mm best guard  133507638
# 2  pertukangan                 Isi Staples Tembak 8 mm best guard  133507638
# 3  pertukangan  steples tembak / staples tembak kenmaster PROM...   88842566
# 4  pertukangan  Staple Gun / Staples Tembak / Staples Jok / He...  209226141
#
#   Terjual  Id_Toko                                                Url  label
# 0     545  1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 1     545  1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 2     545  1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 3      45  1102298  https://www.tokopedia.com/cahayabelawa/steples...      0
# 4     171   580197  https://www.tokopedia.com/hmhhardware/staple-g...      0

# %% [markdown]
# ##C2. Stopwords

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
more_stop_words = []

stop_words = StopWordRemoverFactory().get_stop_words()
new_array = ArrayDictionary(stop_words)
stop_words_remover_new = StopWordRemover(new_array)

def stopword(str_text):
  str_text = stop_words_remover_new.remove(str_text)
  return str_text


df_copy['Ulasan'] = df_copy['Ulasan'].apply(lambda x: stopword(x))
df_copy.head()
# Out:
#    Unnamed: 0                                             Ulasan  Rating  \
# 0          59                       pesanan   sesuai yg d gambar       2
# 1          70  pengiriman respon super cepat. tpi barang sesu...       2
# 2          95                   barang yg dikirim sesuai pesanan       1
# 3         117  php, bilang isi diseskripsi pas dipesen berbed...       1
# 4         153    barang jelek copot&#34; terus tmpat taro isinya       2
#
#       Kategori                                        Nama Produk  Id Produk  \
# 0  pertukangan                 Isi Staples Tembak 8 mm best guard  133507638
# 1  pertukangan                 Isi Staples Tembak 8 mm best guard  133507638
# 2  pertukangan                 Isi Staples Tembak 8 mm best guard  133507638
# 3  pertukangan  steples tembak / staples tembak kenmaster PROM...   88842566
# 4  pertukangan  Staple Gun / Staples Tembak / Staples Jok / He...  209226141
#
#   Terjual  Id_Toko                                                Url  label
# 0     545  1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 1     545  1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 2     545  1461393  https://www.tokopedia.com/timurjaya46/isi-stap...      0
# 3      45  1102298  https://www.tokopedia.com/cahayabelawa/steples...      0
# 4     171   580197  https://www.tokopedia.com/hmhhardware/staple-g...      0

# %% [markdown]
# ## C3. Tokenize

# %%
tokenized = df_copy['Ulasan'].apply(lambda x:x.split())
tokenized
# Out:
# 0                       [pesanan, sesuai, yg, d, gambar]
# 1      [pengiriman, respon, super, cepat., tpi, baran...
# 2                 [barang, yg, dikirim, sesuai, pesanan]
# 3      [php,, bilang, isi, diseskripsi, pas, dipesen,...
# 4      [barang, jelek, copot&#34;, terus, tmpat, taro...
#                              ...
# 995           [bagus, memuaskan., packing, bagus, cepat]
# 996             [mantap, pengiriman, cepat, rekomen, ed]
# 997                        [pengiriman, cepat., lumayan]
# 998              [belom, dicoba, semoga, oke, barangnya]
# 999    [barang, cukup, bagus,, respon, bagus., gak, m...
# Name: Ulasan, Length: 1925, dtype: object
